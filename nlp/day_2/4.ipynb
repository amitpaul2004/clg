# %%
import nltk
from nltk import CFG

# %%
# Generate the parse trees
trees = list(parser.parse(sentence))

# Check if any trees were generated and display them
if not trees:
    print("The brown Fox is quick and he is jumping over the lazy dog.")
else:
    for tree in trees:
        # Option 1: Print the bracketed representation
        print(tree)
        print()
        # Option 2: Print a pretty text-based tree
        tree.pretty_print()
# Out:
# (S (NP (Det the) (N fox)) (VP (V chases) (NP (Det a) (N dog))))
#
#               S
#       ________|_____
#      |              VP
#      |         _____|___
#      NP       |         NP
#   ___|___     |      ___|___
# Det      N    V    Det      N
#  |       |    |     |       |
# the     fox chases  a      dog
