# %%
import re

# %%
S = "Hello world! This is a test paragraph. Does it work? Yes, it does."

# %%
sentences = re.split(r'(?<=[.!?]) +', S)

# %%
print(len(sentences))
# Out:
# 4

# %%
for sentence in sentences:
    print(sentence)
# Out:
# Hello world!
# This is a test paragraph.
# Does it work?
# Yes, it does.
